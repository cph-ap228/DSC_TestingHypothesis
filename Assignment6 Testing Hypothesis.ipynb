# %%
# Structuring Dataframe
import pandas as pd 

# Task (1)
df = pd.read_excel('municipality_cases_2021.xlsx', skiprows = [0])

# %%
df.shape
# Out:
# (59, 100)

# %%
df.head()
# Out:
#    Copenhagen  Aarhus
# 0         183      75
# 1         262     157
# 2         277     111
# 3         360     204
# 4         267     129

# %%
# Task (2)

df = df[["Copenhagen","Aarhus"]]

# %%
df.shape
# Out:
# (59, 2)

# %%
df.head()
# Out:
#    Copenhagen  Aarhus
# 0         183      75
# 1         262     157
# 2         277     111
# 3         360     204
# 4         267     129

# %%
# Task (3)
# DataPlot shows amount of new cases (Y-axis) in relation to each day in a rougly two month period (X-axis)
import pandas as pd 

df = df[["Copenhagen","Aarhus"]]
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #Task (4)
#
# Result shows t-test analyzation performed in Excel.
#
# ![T_Test_Excel.PNG](attachment:T_Test_Excel.PNG)
